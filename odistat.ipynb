# %%
#multiline value graph
import matplotlib.pyplot as plt
#adding title  labels for axis
plt.style.use('seaborn-dark')
#print(plt.style.available)
import matplotlib.pyplot as plt
x=[5,10,15,20,25,30,35,40,45,50]
y=[10,40,68,89,109,135,159,180,224,300]
x1=[5,10,15,20,25,30,35,40,45,50]
y1=[15,37,76,93,111,145,169,190,221,289]
plt.figure(figsize=(15,10))
plt.plot(x,y,'bo-',linewidth=3,label='india')
plt.plot(x1,y1,'ro-',linewidth=3,label='england')
plt.legend(loc='upper left',prop={'size': 20})
plt.grid(True)
plt.title('ODI STAT',fontsize=30)
#plt.axis([0,5,0,10])
plt.xlabel('overs',fontsize=18)
plt.ylabel('runs',fontsize=18)
print(plt.show)
# Out:
# <function show at 0x0000013A787558C8>
